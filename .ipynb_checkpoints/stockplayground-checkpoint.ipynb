# %%
import pandas as pd
import pandas_datareader as pdr
import yfinance as yf
import datetime
import time
#end_date = datetime.datetime.now()
#start_date = "2019-01-01"
symbols = ['AEM.TO', 'AQN.TO', 'ATD.TO', 'BCE.TO', 'BMO.TO', 'BNS.TO', 'ABX.TO', 'BAM-A.TO', 'BIP-UN.TO', 'CAE.TO', 'CCL-B.TO', 'GIB-A.TO', 'CCO.TO', 'CAR-UN.TO', 'CM.TO', 'CNR.TO', 'CNQ.TO', 'CP.TO', 'CTC-A.TO', 'CVE.TO', 'CSU.TO', 'DOL.TO', 'EMA.TO', 'ENB.TO', 'FM.TO', 'FSV.TO', 'FTS.TO', 'FNV.TO', 'WN.TO', 'GIL.TO', 'IMO.TO', 'IFC.TO', 'H.TO', 'K.TO', 'L.TO', 'MG.TO', 'MFC.TO', 'MRU.TO', 'NA.TO', 'NTR.TO', 'OTEX.TO', 'PPL.TO', 'POW.TO', 'QSR.TO', 'RCI-B.TO', 'RY.TO', 'SNC.TO', 'SAP.TO', 'SJR-B.TO', 'SHOP.TO', 'SLF.TO', 'SU.TO', 'TRP.TO', 'TECK-B.TO', 'T.TO', 'TRI.TO', 'TD.TO', 'TOU.TO', 'WCN.TO', 'WPM.TO']
nasdaq = ['^IXIC','ATVI', 'ADBE', 'ADP', 'ABNB', 'ALGN', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AEP', 'AMGN', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ASML', 'AZN', 'TEAM', 'ADSK', 'BIDU', 'BIIB', 'BKNG', 'AVGO', 'CDNS', 'CHTR', 'CTAS', 'CSCO', 'CTSH', 'CMCSA', 'CEG', 'CPRT', 'COST', 'CRWD', 'CSX', 'DDOG', 'DXCM', 'DOCU', 'DLTR', 'EBAY', 'EA', 'EXC', 'FAST', 'FISV', 'FTNT', 'GILD', 'HON', 'IDXX', 'ILMN', 'INTC',
                         'INTU', 'ISRG', 'JD', 'KDP', 'KLAC', 'KHC', 'LRCX', 'LCID', 'LULU', 'MAR', 'MRVL', 'MTCH', 'MELI', 'META', 'MCHP', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MNST', 'NTES', 'NFLX', 'NVDA', 'NXPI', 'ORLY', 'OKTA', 'ODFL', 'PCAR', 'PANW', 'PAYX', 'PYPL', 'PEP', 'PDD', 'QCOM', 'REGN', 'ROST', 'SGEN', 'SIRI', 'SWKS', 'SPLK', 'SBUX', 'SNPS', 'TMUS', 'TSLA', 'TXN', 'VRSN', 'VRSK', 'VRTX', 'WBA', 'WDAY', 'XEL', 'ZM', 'ZS']
sp500 = ['MMM', 'AOS', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT',
                        'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON',
                        'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF-B', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF',
                        'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT',
                        'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FAST', 'FRT', 'FDX', 'FITB', 'FRC', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NLOK', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE',
                        'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PKI', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG',
                        'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SBNY', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN',
                        'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VNO', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']

# %%
def get_data(symbols, time_period):
    #print("Requesting information for " + name)
    #print(start_date, end_date)
    df = yf.download(symbols, period = time_period, threads=True)['Close']
    return df
#df = get_data(nasdaq, '6y')
#df.head()

#filter_five_days("d")

# %%
def filter_five_days(df):
    end_date= datetime.datetime.now() - datetime.timedelta(1)
    start_date= end_date-datetime.timedelta(5)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    while end_week_no >= 5:
        end_date = end_date - datetime.timedelta(1)
        end_week_no = end_date.weekday()
    while start_week_no >= 5 :
        start_date = start_date - datetime.timedelta(1)   
        start_week_no = start_date.weekday()
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', 'Five'])
    while True:
        try:
            for column in df:
                #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
                percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
                df1.loc[len(df1)] = [column, percent_change]

        except:
            start_date = start_date - datetime.timedelta(1)
            s = str(start_date)[:10]
        else:
            break
    return df1

# %%
def filter_ten_days(df):
    end_date= datetime.datetime.now() - datetime.timedelta(1)
    start_date= end_date-datetime.timedelta(10)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    while end_week_no >= 5:
         end_date = end_date - datetime.timedelta(1)
         end_week_no = end_date.weekday()
    while start_week_no >= 5:
        start_date = start_date - datetime.timedelta(1)    
        start_week_no = start_date.weekday()
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', 'Ten'])
    while True:
        try:
            for column in df:
                #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
                percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
                df1.loc[len(df1)] = [column, percent_change]

        except:
            start_date = start_date - datetime.timedelta(1)
            s = str(start_date)[:10]
            continue
        else:
            break
    
    return df1

# %%
def filter_twenty_days(df):
    end_date= datetime.datetime.now() - datetime.timedelta(1)
    start_date = end_date-datetime.timedelta(20)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    while end_week_no >= 5:
        end_date = end_date - datetime.timedelta(1)
        end_week_no = end_date.weekday()
    while start_week_no >= 5:
        start_date = start_date - datetime.timedelta(1)  
        start_week_no = start_date.weekday()
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', 'Twenty'])
    while True:
        try:
            for column in df:
                #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
                percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
                df1.loc[len(df1)] = [column, percent_change]

        except:
            start_date = start_date - datetime.timedelta(1)
            s = str(start_date)[:10]
            continue
        else:
            break
    return df1

# %%
def export_to_xslx(df, file_name):
    df.to_excel(file_name, engine='openpyxl')
    print('writing done')

# %%
def neg_pos(df):
    for column in df:
        if df.loc['Five', column] > 0 and df.loc['Twenty', column] < 0:
            print('There is a twenty day reversal')
            print(df[column])
        elif df.loc['Five', column] > 0 and df.loc['Ten', column] < 0:
            print('There is a ten day reversal')
            print(df[column])
#neg_pos(final.T)

# %%
def filter_year_date(df):
    end_date= datetime.datetime.now() - datetime.timedelta(1)
    start_date= datetime.datetime(2023,1,3)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    while end_week_no >= 5:
        end_date = end_date - datetime.timedelta(1)
        end_week_no = end_date.weekday()
    while start_week_no >= 5:
        start_date = start_date - datetime.timedelta(1)   
        start_week_no = start_date.weekday()
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', 'YTD'])\
    while True
        try:
            for column in df:
                #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
                percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
                df1.loc[len(df1)] = [column, percent_change]
        except:
            start_date = start_date - datetime.timedelta(1)
            s = str(start_date)[:10]
        else:
            break
    
    return df1
        
def filter_year(df):
    end_date= datetime.datetime(2022,12,30)
    start_date= datetime.datetime(2021,12,31)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    while end_week_no >= 5:
        end_date = end_date - datetime.timedelta(1)
        end_week_no = end_date.weekday()
    while start_week_no >= 5:
        start_date = start_date - datetime.timedelta(2)   
        start_week_no = start_date.weekday()
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', '1Y CHANGE'])
    try:
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    except:
        start_date = start_date - datetime.timedelta(1)
        s = str(start_date)[:10]
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    return df1

def filter_two_year(df):
    end_date = datetime.datetime(2021,12,31)
    start_date = datetime.datetime(2020,12,31)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    while end_week_no >= 5:
        end_date = end_date - datetime.timedelta(1)
        end_week_no = end_date.weekday()
    while start_week_no >= 5:
        start_date = start_date - datetime.timedelta(1)    
        start_week_no = start_date.weekday()
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', '2Year CHANGE'])
    try:
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    except:
        start_date = start_date - datetime.timedelta(1)
        s = str(start_date)[:10]
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    return df1

def filter_three_year(df):
    end_date = datetime.datetime(2020,12,31)
    start_date = datetime.datetime(2019,12,31)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    if end_week_no >= 6:
        end_date = end_date - datetime.timedelta(2)
    elif start_week_no >= 6:
        start_date = start_date - datetime.timedelta(2)    
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', '3Year CHANGE'])
    try:
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    except:
        start_date = start_date - datetime.timedelta(1)
        s = str(start_date)[:10]
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    return df1

def filter_four_year(df):
    end_date = datetime.datetime(2019,12,31)
    start_date = datetime.datetime(2018,12,31)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    if end_week_no >= 6:
        end_date = end_date - datetime.timedelta(2)
    elif start_week_no >= 6:
        start_date = start_date - datetime.timedelta(2)    
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', '4Year CHANGE'])
    try:
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    except:
        start_date = start_date - datetime.timedelta(1)
        s = str(start_date)[:10]
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    return df1

def filter_five_year(df):
    end_date = datetime.datetime(2018,12,31)
    start_date = datetime.datetime(2017,12,29)
    end_week_no = end_date.weekday()
    start_week_no = start_date.weekday()
    if end_week_no >= 6:
        end_date = end_date - datetime.timedelta(2)
    elif start_week_no >= 6:
        start_date = start_date - datetime.timedelta(2)    
    e = str(end_date)[:10]
    s = str(start_date)[:10]
    df1 = pd.DataFrame(columns=['Symbol', '5Year CHANGE'])
    try:
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    except:
        start_date = start_date - datetime.timedelta(1)
        s = str(start_date)[:10]
        for column in df:
            #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
            percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
            df1.loc[len(df1)] = [column, percent_change]
    
    return df1

# %%
def make_sheets():
    tsx = ['AEM.TO', 'AQN.TO', 'ATD.TO', 'BCE.TO', 'BMO.TO', 'BNS.TO', 'ABX.TO', 'BAM-A.TO', 'BIP-UN.TO', 'CAE.TO', 'CCL-B.TO', 'GIB-A.TO', 'CCO.TO', 'CAR-UN.TO', 'CM.TO', 'CNR.TO', 'CNQ.TO', 'CP.TO', 'CTC-A.TO', 'CVE.TO', 'CSU.TO', 'DOL.TO', 'EMA.TO', 'ENB.TO', 'FM.TO', 'FSV.TO', 'FTS.TO', 'FNV.TO', 'WN.TO', 'GIL.TO', 'IMO.TO', 'IFC.TO', 'H.TO', 'K.TO', 'L.TO', 'MG.TO', 'MFC.TO', 'MRU.TO', 'NA.TO', 'NTR.TO', 'OTEX.TO', 'PPL.TO', 'POW.TO', 'QSR.TO', 'RCI-B.TO', 'RY.TO', 'SNC.TO', 'SAP.TO', 'SJR-B.TO', 'SHOP.TO', 'SLF.TO', 'SU.TO', 'TRP.TO', 'TECK-B.TO', 'T.TO', 'TRI.TO', 'TD.TO', 'TOU.TO', 'WCN.TO', 'WPM.TO']
    nasdaq = ['^IXIC','ATVI', 'ADBE', 'ADP', 'ABNB', 'ALGN', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AEP', 'AMGN', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ASML', 'AZN', 'TEAM', 'ADSK', 'BIDU', 'BIIB', 'BKNG', 'AVGO', 'CDNS', 'CHTR', 'CTAS', 'CSCO', 'CTSH', 'CMCSA', 'CEG', 'CPRT', 'COST', 'CRWD', 'CSX', 'DDOG', 'DXCM', 'DOCU', 'DLTR', 'EBAY', 'EA', 'EXC', 'FAST', 'FISV', 'FTNT', 'GILD', 'HON', 'IDXX', 'ILMN', 'INTC',
                         'INTU', 'ISRG', 'JD', 'KDP', 'KLAC', 'KHC', 'LRCX', 'LCID', 'LULU', 'MAR', 'MRVL', 'MTCH', 'MELI', 'META', 'MCHP', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MNST', 'NTES', 'NFLX', 'NVDA', 'NXPI', 'ORLY', 'OKTA', 'ODFL', 'PCAR', 'PANW', 'PAYX', 'PYPL', 'PEP', 'PDD', 'QCOM', 'REGN', 'ROST', 'SGEN', 'SIRI', 'SWKS', 'SPLK', 'SBUX', 'SNPS', 'TMUS', 'TSLA', 'TXN', 'VRSN', 'VRSK', 'VRTX', 'WBA', 'WDAY', 'XEL', 'ZM', 'ZS']
    sp500 = ['MMM', 'AOS', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT',
                        'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON',
                        'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF-B', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF',
                        'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT',
                        'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FAST', 'FRT', 'FDX', 'FITB', 'FRC', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE',
                        'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PKI', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG',
                        'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SBNY', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN',
                        'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VNO', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
    symbols = [tsx, nasdaq, sp500]
    symbols1 = ['tsx', 'nasdaq', 'sp500'] 
    
    for i, symbol in enumerate(symbols):
        df = get_data(symbol, '6y')
        
        filtered = filter_five_days(df)
        a = filtered.sort_values(by=['Five'],ascending=False)
        filtered_ten = filter_ten_days(df)
        b = filtered_ten.sort_values(by=['Ten'],ascending=False)
        filtered_twenty = filter_twenty_days(df)
        c = filtered_twenty.sort_values(by=['Twenty'],ascending=False)
        
        year_to_date = filter_year_date(df)
        filtered_year = filter_year(df)
        filtered_two_year = filter_two_year(df)
        filtered_three_year = filter_three_year(df)
        filtered_four_year = filter_four_year(df)
        filtered_five_year = filter_five_year(df)

        final = a.join(b.set_index('Symbol'), on='Symbol').join(c.set_index('Symbol'), on='Symbol')
        final1 = final.join(year_to_date.set_index('Symbol'), on='Symbol').join(filtered_year.set_index('Symbol'), on='Symbol').join(filtered_two_year.set_index('Symbol'), on='Symbol').join(filtered_three_year.set_index('Symbol'), on='Symbol').join(filtered_four_year.set_index('Symbol'), on='Symbol').join(filtered_five_year.set_index('Symbol'), on='Symbol')

        #final1.set_index('Symbol')
        #laoshu = final1.join(df.T)

        final1 = final1.sort_values(by=['Symbol'],ascending=True)
        final1 = final1.set_index('Symbol')
        #x = final1.join(df.sort_values(by=['Date'], ascending=False).T)
        #export_to_xslx(x.T, f'{symbols1[i]}.xlsx')
make_sheets()
# Out:
# [*********************100%***********************]  60 of 60 completed
# 6
# 1
# 6
# 0
# 2022-12-26 12:25:32.912784
# 2022-12-26
# 2022-12-25 12:25:32.912784
# 2022-12-24 12:25:32.912784
# 2022-12-23 12:25:32.912784
# 0
# 1
#                ABX.TO     AEM.TO  AQN.TO     ATD.TO   BAM-A.TO     BCE.TO  \
# Date
# 2023-01-11  177.419998  174.389999  58.090000
# 2023-01-12  171.009995  171.679993  58.860001
# 2023-01-13  174.789993  171.889999  59.619999
# 2023-01-16  176.039993  172.104996  59.380001
#
# [1506 rows x 60 columns]
# [*********************100%***********************]  103 of 103 completed
# 6
# 1
# 6
# 0
# 2022-12-26 12:25:37.467304
# 2022-12-26
# 2022-12-25 12:25:37.467304
# 2022-12-24 12:25:37.467304
# 2022-12-23 12:25:37.467304
# 0
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1673827200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2023-01-16 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('2023-01-16 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 18, in filter_year_date(df)
#      16 for column in df:
#      17     #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
# ---> 18     percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
#      19     df1.loc[len(df1)] = [column, percent_change]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
#    1249 # no multi-index, so validate all of the indexers
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:967, in _LocationIndexer._getitem_lowerdim(self, tup)
#     964 if is_label_like(key):
#     965     # We don't need to check for tuples here because those are
#     966     #  caught by the _is_nested_tuple_indexer check above.
# --> 967     section = self._getitem_axis(key, axis=i)
#     969     # We should never have a scalar section here, because
#     970     #  _getitem_lowerdim is only called after a check for
#     971     #  is_scalar_access, which that would be.
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: '2023-01-16'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1673827200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2023-01-16 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('2023-01-16 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 44
#      41         print(df)
#      42         #x = final1.join(df.sort_values(by=['Date'], ascending=False).T)
#      43         #export_to_xslx(x.T, f'{symbols1[i]}.xlsx')
# ---> 44 make_sheets()
#
# Cell In[14], line 26, in make_sheets()
#      23 filtered_twenty = filter_twenty_days(df)
#      24 c = filtered_twenty.sort_values(by=['Twenty'],ascending=False)
# ---> 26 year_to_date = filter_year_date(df)
#      27 filtered_year = filter_year(df)
#      28 filtered_two_year = filter_two_year(df)
#
# Cell In[13], line 26, in filter_year_date(df)
#      23     s = str(start_date)[:10]
#      24     for column in df:
#      25         #print(column, 'Percent change', (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100)
# ---> 26         percent_change = (df.loc[e,column] - df.loc[s, column])/df.loc[s, column]*100
#      27         df1.loc[len(df1)] = [column, percent_change]
#      29 return df1
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1245 with suppress(IndexingError):
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
#    1249 # no multi-index, so validate all of the indexers
#    1250 tup = self._validate_tuple_indexer(tup)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:967, in _LocationIndexer._getitem_lowerdim(self, tup)
#     963 for i, key in enumerate(tup):
#     964     if is_label_like(key):
#     965         # We don't need to check for tuples here because those are
#     966         #  caught by the _is_nested_tuple_indexer check above.
# --> 967         section = self._getitem_axis(key, axis=i)
#     969         # We should never have a scalar section here, because
#     970         #  _getitem_lowerdim is only called after a check for
#     971         #  is_scalar_access, which that would be.
#     972         if section.ndim == self.ndim:
#     973             # we're in the middle of slicing through a MultiIndex
#     974             # revise the key wrt to `section` by inserting an _NS
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: '2023-01-16'

# %%
def make_sheets(stock_list,file_name):
    df = get_data(stock_list, '6y')
        
    filtered = filter_five_days(df)
    a = filtered.sort_values(by=['Five'],ascending=False)
    filtered_ten = filter_ten_days(df)
    b = filtered_ten.sort_values(by=['Ten'],ascending=False)
    filtered_twenty = filter_twenty_days(df)
    c = filtered_twenty.sort_values(by=['Twenty'],ascending=False)
        
    year_to_date = filter_year_date(df)
    filtered_year = filter_year(df)
    filtered_two_year = filter_two_year(df)
    filtered_three_year = filter_three_year(df)
    filtered_four_year = filter_four_year(df)
    filtered_five_year = filter_five_year(df)

    final = a.join(b.set_index('Symbol'), on='Symbol').join(c.set_index('Symbol'), on='Symbol')
    final1 = final.join(year_to_date.set_index('Symbol'), on='Symbol').join(filtered_year.set_index('Symbol'), on='Symbol').join(filtered_two_year.set_index('Symbol'), on='Symbol').join(filtered_three_year.set_index('Symbol'), on='Symbol').join(filtered_four_year.set_index('Symbol'), on='Symbol').join(filtered_five_year.set_index('Symbol'), on='Symbol')

        #final1.set_index('Symbol')
        #laoshu = final1.join(df.T)

    final1 = final1.sort_values(by=['Symbol'],ascending=True)
    final1 = final1.set_index('Symbol')
    x = final1.join(df.sort_values(by=['Date'], ascending=False).T)
    export_to_xslx(x.T, f'{file_name}.xlsx')

# %%
make_sheets(['AAPL','AMD'], 'Name')
